# %%
def busca_binaria(lista, alvo):
  l = 0
  h = len(lista) - 1
  while l <= h:
    m = (l + h) // 2
    if lista[m] == alvo:
      return m
    elif lista[m] < alvo:
      l = m + 1
    else:
      h = m -1
  return -1


lista = [2, 3, 5, 7,  8,  10, 12, 15, 18, 20]
alvo = 7
resultado = busca_binaria(lista, alvo)

if resultado != -1:
  print(f"O alvo {alvo} foi encontrado no indice {resultado}")
else:
  print("O alvo não foi encontrado")

# %%
def busca_binaria(lista, alvo):
  l = 0
  h = len(lista) - 1
  while l <= h:
    m = (l + h) // 2
    if lista[m] == alvo:
      return m
    elif lista[m] > alvo:
      h = m -1
    else:
      l = m + 1
  return - 1


lista = [1250, 3500, 4000, 5000, 5500, 6000, 7000]
alvo = 4000
resultado = busca_binaria(lista, alvo)

if resultado != -1:
  print(f"O alvo encontrado está no índice {resultado}")
else:
  print("O alvo não foi encontrado")

# %%
salarios = [5000, 6000, 4000, 5500, 3500, 1250, 7000]
alvo = 5500

salarios.sort()
print(salarios)

def busca_binaria(salarios, alvo):
  l = 0
  h = len(salarios) - 1
  while l <= h:
    m = (l + h) // 2
    if salarios[m] == alvo:
      return m
    elif salarios[m] > alvo:
      h = m - 1
    else:
      l = m + 1
  return - 1

resultado = busca_binaria(salarios, alvo)

if resultado != -1:
  print(f"O indice do alvo é {resultado}")
else:
  print("Alvo não encontrado")

# %%
for i in range(5):
  print(f"Dados da {i + 1} pessoa")

  nome = input("Insira o nome: ")
  salario = float(input("Insira o salário: "))
  lista.append((nome, salario))

print(lista)

lista_salario = sorted(lista, key=lambda x: x[1])
print(lista_salario)

alvo = float(input("Qual salário você quer buscar: "))

def busca_binaria(lista_salario, alvo):
  l = 0
  h = len(lista_salario) - 1
  while l <= h:
    m = (l + h) // 2
    if lista_salario[m][1] == alvo:
      return m
    elif lista_salario[m][1] < alvo:
      l = m + 1
    else:
      h = m - 1
  return -1

resultado = busca_binaria(lista_salario, alvo)

if resultado != -1:
  print(f"Funcionário encontrado: {lista_salario[resultado][0]}, salário: {lista_salario[resultado][1]}")
else:
  print("O alvo não foi encontrado")

# %%
salarios = [5000, 6000, 4000, 5500, 3500, 1250, 7000]
salarios.sort()
print(salarios)
alvo = 5500

def busca_binaria(salarios, alvo):
  l = 0
  h = len(salarios) - 1
  while l <= h:
    m = (l + h) // 2
    if salarios[m] == alvo:
      return m
    elif salarios[m] > alvo:
      h = m -1
    else:
      l = m + 1
  return -1


resultado = busca_binaria(salarios, alvo)

if resultado != -1:
  print(f"O alvo {alvo} foi encontrado no indice {resultado}")
else:
  print("O alvo não foi encontrado")

# %%
salarios = [5000, 6000, 4000, 5500, 3500, 1250, 7000]
salarios.sort()
print(salarios)

alvo = 5500

def busca_binaria(salarios, alvo):
  l = 0
  h = len(salarios) - 1
  while l <= h:
    m = (l + h) // 2
    if salarios[m] == alvo:
      return m
    elif salarios[m] > alvo:
      h = m -1
    else:
      l = m -1
  return -1

resultado = busca_binaria(salarios, alvo)

if resultado != -1:
  print(f"O alvo {alvo} foi encontrado no indice {resultado}")
else:
  print("O resultado não foi encontrado")

# %%
lista = [11, 17, 18, 45, 50, 71, 95]
alvo = 50

def busca_binaria(lista, alvo):
  l = 0
  h = len(lista) - 1
  while l <= h:
    m = (l + h) // 2
    if lista[m] == alvo:
      return m
    elif lista[m] > alvo:
      h = m -1
    else:
      l = m - 1
  return -1

resultado = busca_binaria(lista, alvo)
if resultado != -1:
  print(f"O indice do alvo {alvo} é {resultado}")
else:
  print("O indice não foi encontrado")

# %%
lista = [11, 17, 18, 45, 50, 71, 95]
alvo = 50

def busca_binaria(lista, alvo):
  l = 0
  h = len(lista) - 1
  for i in range(len(lista)):
    if lista[i] == alvo:
      return i
    elif lista[i] > alvo:
      h = i -1
    else:
      l = i -1
  return -1

resultdo = busca_binaria(lista, alvo)
if resultado != -1:
  print(f"O indice do alvo {alvo} é {resultado}")
else:
  print("O indice não foi encontrado")

# %%
lista = [2, 3, 5, 7, 8, 10, 12, 15, 18, 20]
alvo = 7

def busca_binaria(lista, alvo):
  l = 0
  h = len(lista) - 1
  contador = 1

  while l <= h:
    m = (l + h) // 2
    print(f"Contador {contador}: m = {m}, l = {l}, h = {h}")
    if lista[m] == alvo:
      return m
    elif lista[m] > alvo:
      h = m - 1
    else:
      l = m + 1
    contador += 1
  return -1

resultado = busca_binaria(lista, alvo)
if resultado != -1:
  print(f"O indice do alvo {alvo} é {resultado}")
else:
  print("O indice não foi encontrado")

# %%
numeros = []

for i in range(8):
  num = float(input("Digite 8 números: "))
  numeros.append(num)

numeros.sort()
print(numeros)

alvo = float(input("Digite um número acima para ser o alvo"))

def busca_binaria(numeros, alvo):
  l = 0
  h = len(numeros) - 1
  while l <= h:
    m = (l + h) // 2
    if numeros[m] == alvo:
      return m
    elif numeros[m] > alvo:
      h = m - 1
    else:
      l = m + 1
  return -1

resultado = busca_binaria(numeros, alvo)
if resultado != -1:
  print(f"O alvo {alvo} está no índice {resultado}")
else:
  print("O alvo não foi encontrado")

# %%
comidas = [("Arroz", 5.50), ("Feijão", 8.90), ("Leite", 4.20), ("Oleo", 9.80), ("Macarrao", 3.10)]

comidas1 = sorted(comidas, key=lambda x: x[1])
print(comidas1)

precos = [item[1] for item in comidas1]
print(precos)

alvo = 8.90

def busca_binaria(precos, alvo):
  l = 0
  h = len(precos) - 1
  while l <= h:
    m = (l + h) // 2
    if precos[m] == alvo:
      return m
    elif precos[m] > alvo:
      h = m -1
    else:
      l = m + 1
  return -1

resulatdo = busca_binaria(precos, alvo)
if resultado != -1:
  print(f"O indice do alvo {alvo} é {resultdo}")
else:
  print("O alvo não foi encontrado")

# %%
comidas = [("Arroz", 5.50), ("Feijão", 8.90), ("Leite", 4.20), ("Oleo", 9.80), ("Macarrao", 3.10)]

comidas1 = sorted(comidas, key=lambda x: x[1])
print(comidas1)

precos = [item[1] for item in comidas1]

alvo = 8.90

def busca_binaria(precos, alvo):
  l = 0
  h = len(precos) - 1
  while l <= h:
    m = (l + h) // 2
    if precos[m] == alvo:
      return m
    elif precos[m] > alvo:
      h = m - 1
    else:
      l = m + 1
  return -1

resultado = busca_binaria(precos, alvo)
if resultado != -1:
  print(f"O indice do alvo {alvo} é {resultdo}")
else:
  print("O alvo não foi encontrado")

# %%
lista = [5000, 6000, 4000, 5500, 3500, 1250, 7000]
lista.sort()
print(lista)

alvo = 5500

def busca_binaria(lista, alvo):
  l = 0
  h = len(lista) - 1
  contador = 1

  while l <= h:
    m = (l + h) // 2
    print(f"O contador {contador}: m = {m}, l = {l}, h = {h}")

    if lista[m] == alvo:
      return m
    elif lista[m] > alvo:
      h = m - 1
    else:
      l = m + 1
    contador += 1
  return -1

resultado = busca_binaria(lista, alvo)
if resultado != -1:
  print(f"O indice do alvo {alvo} é {resultdo}")
else:
  print("O alvo não foi encontrado")

# %%
lista = [10, 20, 30, 40, 50]
alvo = 25

def busca_binaria(lista, alvo):
  l = 0
  h = len(lista) - 1

  while l <= h:

    m = (l + h) // 2
    if lista[m] == alvo:
      return m
    elif lista[m] > alvo:
      h = m - 1
    else:
      l = m + 1
  return -1

resultado = busca_binaria(lista, alvo)
if resultado != -1:
  print(f"o indice do alvo {alvo} é {resultado}")
else:
  print("-1")
